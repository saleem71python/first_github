# %% [markdown]
# # import libraries

# %% [markdown]
# # -seborn automatically install these libraries
# # -numpy
# # -scipy
# # -pandas
# # -matplotlib

# %% [markdown]
# #adding titles

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool=sns.load_dataset("iris")
phool
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
plt.show()

# %% [markdown]
# # adding limits

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool=sns.load_dataset("iris")
phool
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
plt.xlim(2)
plt.ylim(2)
plt.show()

# %% [markdown]
# # set styles
#
# # -darkgrid
# # -whitegrid
# # -dark
# # -white
# # -ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool=sns.load_dataset("iris")
# change figure
plt.figure(figsize=(10,8))
phool
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
sns.set_style("dark")
# set_style(stule=None,rc=None) # go goole and help for this assignment
plt.show()

# %% [markdown]
# #size of figure

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool=sns.load_dataset("iris")
phool
sns.lineplot(x="sepal_length",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
sns.set_style(style=None,rc=None)
sns.set_style("dark")

plt.show()

# %% [markdown]
# ## 02-bar plots

# %%
 #import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool=sns.load_dataset("iris")
phool
sns.barplot(x="species",y="sepal_width",data=phool)
plt.title("phoolon ka plot")
plt.show()

# %%
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool=sns.load_dataset("iris")
phool
sns.barplot(x="species",y="petal_length",data=phool)
plt.title("phoolon ka plot")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="who",y="alone",hue="sex",data=kashti)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue="who",data=kashti)
plt.show()

# %% [markdown]
# # how set the order( order of male and female)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue="who",data=kashti,order=["female","male"])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue="who",data=kashti,order=["female","male"],color="blue")
plt.show()

# %% [markdown]
# # remove error bars by using ci(confidence intercal)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue="who",data=kashti,order=["female","male"],color="blue",ci=None)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="sex",y="alone",hue="who",data=kashti,order=["female","male"],color="red",ci=None,palette="pastel")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy
#load dataset
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="class",y="fare",hue="sex",data=kashti, estimator=median)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean
#load dataset
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="class",y="fare",hue="sex",data=kashti, estimator=mean)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy
#load dataset
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="class",y="fare",hue="sex",data=kashti, estimator=mean,saturation=(0.5))

plt.show()

# %% [markdown]
# # horizontal plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy
#load dataset
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="fare",y="class",hue="sex",data=kashti, estimator=mean,saturation=(1))

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")

sns.barplot(x="class",y="fare",data=kashti,
            linewidth=3,facecolor=(1,1,1,0),
            errcolor=".2",edgecolor=".2")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti=sns.load_dataset("titanic")

sns.barplot(x="class",y="fare",data=kashti,
            linewidth=3,facecolor=(0.5,0.3,0.5,0.5),
            errcolor=".2",edgecolor=".2")
plt.show()
